# %% [markdown]
# ## MEDICAL INSURANCE

# %% [markdown]
# #### LOAD LIBRARIES

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# #### IMPORT DATASET

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### NULL VALUE CHECKING

# %%
df['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# #### CHECK DUPLICATES

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=df.drop_duplicates()

# %% [markdown]
# #### SPLIT X AND Y

# %%
x = df.drop('charges', axis=1)

# %%
y = df.charges

# %% [markdown]
# #### ENCODE CATEGORICAL COLUMNS AND SCALE NUMERICAL COLUMNS

# %%
catgrcl_colms= ['sex','smoker','region']
numbr_cols= ['age','bmi','children']

# %%
preprocessor =ColumnTransformer(transformers=[('num', StandardScaler(),numbr_cols),
                                            ('cat', OneHotEncoder(drop='first'), catgrcl_colms)])

x= preprocessor.fit_transform(x)

# %% [markdown]
# #### TRAIN TEST SPLIIT

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %% [markdown]
# #### BUILD ANN MODEL

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape = (x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)])
# Out:
# C:\Users\basim\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### COMPILE MODEL

# %%
model.compile(optimizer='adam', loss='mse',metrics=['mae'])

# %% [markdown]
# #### TRAIN THE MODEL

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    verbose=1)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 305559584.0000 - mae: 13062.8008 - val_loss: 316761120.0000 - val_mae: 12730.1777
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 305501472.0000 - mae: 13060.6904 - val_loss: 316679168.0000 - val_mae: 12727.2402
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 305368768.0000 - mae: 13056.0713 - val_loss: 316487904.0000 - val_mae: 12720.6123
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 305074656.0000 - mae: 13045.9453 - val_loss: 316092160.0000 - val_mae: 12707.2617
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 304509504.0000 - mae: 13027.0088 - val_loss: 315375936.0000 - val_mae: 12683.5605
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 303547040.0000 - mae: 12994.9297 - val_loss: 314172160.0000 - val_mae: 12644.6191
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 301986112.0000 - mae: 12942.5342 - val_loss: 312321984.0000 - val_mae: 12584.7920
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 299681632.0000 - mae: 12866.0146 - val_loss: 309697312.0000 - val_mae: 12501.6963
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 296616448.0000 - mae: 12764.1055 - val_loss: 306261344.0000 - val_mae: 12392.9414
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 292598752.0000 - mae: 12633.3984 - val_loss: 301949184.0000 - val_mae: 12255.8672
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 287681376.0000 - mae: 12464.0488 - val_loss: 296420448.0000 - val_mae: 12079.9346
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 281557504.0000 - mae: 12256.7148 - val_loss: 289989920.0000 - val_mae: 11871.9785
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 274266624.0000 - mae: 12010.1758 - val_loss: 282313504.0000 - val_mae: 11621.8291
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 265935632.0000 - mae: 11724.1748 - val_loss: 273917408.0000 - val_mae: 11337.8740
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 256914016.0000 - mae: 11398.2549 - val_loss: 264372800.0000 - val_mae: 11016.2100
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 246859248.0000 - mae: 11042.9668 - val_loss: 254465136.0000 - val_mae: 10671.0938
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 236320544.0000 - mae: 10655.2422 - val_loss: 243412880.0000 - val_mae: 10287.4043
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 224781536.0000 - mae: 10235.2051 - val_loss: 231894880.0000 - val_mae: 9894.2070
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 212849680.0000 - mae: 9790.3750 - val_loss: 219750464.0000 - val_mae: 9469.3027
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss:
100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57155008.0000 - mae: 5690.2119 - val_loss: 60565684.0000 - val_mae: 5450.0396
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56492928.0000 - mae: 5650.4976 - val_loss: 59885844.0000 - val_mae: 5415.1113
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55809372.0000 - mae: 5581.8882 - val_loss: 59366820.0000 - val_mae: 5375.8779
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55110644.0000 - mae: 5540.7593 - val_loss: 58593824.0000 - val_mae: 5350.2744
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 54421372.0000 - mae: 5516.2651 - val_loss: 57812888.0000 - val_mae: 5333.7153
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53776328.0000 - mae: 5481.2041 - val_loss: 57098224.0000 - val_mae: 5305.8428
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53119400.0000 - mae: 5460.7769 - val_loss: 56384412.0000 - val_mae: 5291.1260
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 52481380.0000 - mae: 5418.8794 - val_loss: 55762048.0000 - val_mae: 5252.7524
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51875688.0000 - mae: 5373.0967 - val_loss: 55137564.0000 - val_mae: 5214.2012
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51231732.0000 - mae: 5334.8765 - val_loss: 54429248.0000 - val_mae: 5180.1387
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50603060.0000 - mae: 5307.6616 - val_loss: 53742672.0000 - val_mae: 5159.3574
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50005988.0000 - mae: 5285.6782 - val_loss: 52963660.0000 - val_mae: 5134.3203
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49394080.0000 - mae: 5237.7832 - val_loss: 52328300.0000 - val_mae: 5090.6299
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48842424.0000 - mae: 5215.0127 - val_loss: 51687104.0000 - val_mae: 5075.3296
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48280360.0000 - mae: 5173.4473 - val_loss: 51142324.0000 - val_mae: 5036.1885
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47743176.0000 - mae: 5180.4136 - val_loss: 50370024.0000 - val_mae: 5039.1011
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47137492.0000 - mae: 5137.2573 - val_loss: 49775788.0000 - val_mae: 5001.1938
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46611632.0000 - mae: 5131.3760 - val_loss: 49026916.0000 - val_mae: 4998.4741
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46076696.0000 - mae: 5126.1133 - val_loss: 48287088.0000 - val_mae: 4981.8325

# %% [markdown]
# #### EVALUATE MODEL

# %%
loss, mae = model.evaluate(x_test, y_test)
print("Mean Absolute Error:", mae)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54298340.0000 - mae: 5435.2021
# Mean Absolute Error: 5435.2021484375

# %% [markdown]
# #### MAKE PREDICTION

# %%
pred = model.predict(x_test[:5])
print(pred)
print(y_test[:5].values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [[ 8396.753 ]
#  [ 7775.0166]
#  [15047.877 ]
#  [28025.273 ]
#  [12675.415 ]]
# [ 8688.85885  5708.867   11436.73815 38746.3551   4463.2051 ]

# %% [markdown]
# #### MODEL SUMMARY

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,069 (31.52 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,380 (21.02 KB)

# %% [markdown]
# #### MODEL SAVING

# %%
model.save('med_ins_ann.keras')

# %%
from tensorflow.keras.models import load_model
model = load_model('med_ins_ann.h5', compile=False)

# %%
x_train.shape[1]
# Out:
# 8

# %%
x_train
# Out:
# array([[-1.15549877, -1.00906256, -0.90923416, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.29795825, -0.80654334,  0.75035092, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.91016372,  1.12517847,  0.75035092, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.36918799, -1.42066033, -0.07944162, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.08705265, -0.43676128,  1.58014347, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.30074188,  0.85214648,  0.75035092, ...,  0.        ,
#          1.        ,  0.        ]])
